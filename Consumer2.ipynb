# %%
import pandas as pd
import numpy as np
from kafka import KafkaConsumer
from kafka import TopicPartition
from kafka import KafkaProducer
   
consumer = KafkaConsumer('raw_tweets', bootstrap_servers = '192.168.99.100:29092')
for msg in consumer: print('sucess')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-bcafe08846d6> in <module>()
#       6
#       7 consumer = KafkaConsumer('raw_tweets', bootstrap_servers = '192.168.99.100:29092')
# ----> 8 for msg in consumer: print('sucess')
#
# ~\AppData\Local\Continuum\Anaconda3\lib\site-packages\kafka\consumer\group.py in __next__(self)
#    1116         self._set_consumer_timeout()
#    1117         try:
# -> 1118             return next(self._iterator)
#    1119         except StopIteration:
#    1120             self._iterator = None
#
# ~\AppData\Local\Continuum\Anaconda3\lib\site-packages\kafka\consumer\group.py in _message_generator(self)
#    1060             if not self._fetcher.in_flight_fetches():
#    1061                 poll_ms = min(poll_ms, self.config['reconnect_backoff_ms'])
# -> 1062             self._client.poll(timeout_ms=poll_ms)
#    1063
# ...
